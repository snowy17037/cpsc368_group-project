# %%
import pandas as pd
import pymongo

# Connect to MongoDB
CWL = "syano02"
SNUM = "60553674"

connection_string = f"mongodb://{CWL}:a{SNUM}@localhost:27017/{CWL}"
client = pymongo.MongoClient(connection_string, serverSelectionTimeoutMS=5000)

# test that the tunnel/database connection works
client.admin.command("ping")
print("Connected to MongoDB.")

db = client[CWL]
movies_collection = db["movies"]
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[2], line 12
#       9 client = pymongo.MongoClient(connection_string, serverSelectionTimeoutMS=5000)
#      11 # test that the tunnel/database connection works
# ---> 12 client.admin.command("ping")
#      13 print("Connected to MongoDB.")
#      15 db = client[CWL]
#
# File ~/.local/lib/python3.13/site-packages/pymongo/_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File ~/.local/lib/python3.13/site-packages/pymongo/synchronous/database.py:934, in Database.command(self, command, value, check, allowable_errors, read_preference, codec_options, session, comment, **kwargs)
#     932 if read_preference is None:
#     933     read_preference = (session and session._txn_read_preference()) or ReadPreference.PRIMARY
# --> 934 with self._client._conn_for_reads(read_preference, session, operation=command_name) as (
#     935     connection,
#     936     read_preference,
#     937 ):
#     938     return self._command(
#     939         connection,
#     940         command,
#    (...)    947         **kwargs,
#     948     )
#
# File ~/.local/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:1885, in MongoClient._conn_for_reads(self, read_preference, session, operation)
#    1878 def _conn_for_reads(
#    1879     self,
#    1880     read_preference: _ServerMode,
#    1881     session: Optional[ClientSession],
#    1882     operation: str,
#    1883 ) -> ContextManager[tuple[Connection, _ServerMode]]:
#    1884     assert read_preference is not None, "read_preference must not be None"
# -> 1885     server = self._select_server(read_preference, session, operation)
#    1886     return self._conn_from_server(read_preference, server, session)
#
# File ~/.local/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:1833, in MongoClient._select_server(self, server_selector, session, operation, address, deprioritized_servers, operation_id)
#    1831             raise AutoReconnect("server %s:%s no longer available" % address)  # noqa: UP031
#    1832     else:
# -> 1833         server = topology.select_server(
#    1834             server_selector,
#    1835             operation,
#    1836             deprioritized_servers=deprioritized_servers,
#    1837             operation_id=operation_id,
#    1838         )
#    1839     return server
#    1840 except PyMongoError as exc:
#    1841     # Server selection errors in a transaction are transient.
#
# File ~/.local/lib/python3.13/site-packages/pymongo/synchronous/topology.py:428, in Topology.select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     418 def select_server(
#     419     self,
#     420     selector: Callable[[Selection], Selection],
#    (...)    425     operation_id: Optional[int] = None,
#     426 ) -> Server:
#     427     """Like select_servers, but choose a random server if several match."""
# --> 428     server = self._select_server(
#     429         selector,
#     430         operation,
#     431         server_selection_timeout,
#     432         address,
#     433         deprioritized_servers,
#     434         operation_id=operation_id,
#     435     )
#     436     if _csot.get_timeout():
#     437         _csot.set_rtt(server.description.min_round_trip_time)
#
# File ~/.local/lib/python3.13/site-packages/pymongo/synchronous/topology.py:402, in Topology._select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     393 def _select_server(
#     394     self,
#     395     selector: Callable[[Selection], Selection],
#    (...)    400     operation_id: Optional[int] = None,
#     401 ) -> Server:
# --> 402     servers = self.select_servers(
#     403         selector,
#     404         operation,
#     405         server_selection_timeout,
#     406         address,
#     407         operation_id,
#     408         deprioritized_servers,
#     409     )
#     410     if len(servers) == 1:
#     411         return servers[0]
#
# File ~/.local/lib/python3.13/site-packages/pymongo/synchronous/topology.py:298, in Topology.select_servers(self, selector, operation, server_selection_timeout, address, operation_id, deprioritized_servers)
#     295     self.cleanup_monitors()
#     297 with self._lock:
# --> 298     server_descriptions = self._select_servers_loop(
#     299         selector,
#     300         server_timeout,
#     301         operation,
#     302         operation_id,
#     303         address,
#     304         deprioritized_servers=deprioritized_servers,
#     305     )
#     307     return [
#     308         cast(Server, self.get_server_by_address(sd.address)) for sd in server_descriptions
#     309     ]
#
# File ~/.local/lib/python3.13/site-packages/pymongo/synchronous/topology.py:359, in Topology._select_servers_loop(self, selector, timeout, operation, operation_id, address, deprioritized_servers)
#     348     if _SERVER_SELECTION_LOGGER.isEnabledFor(logging.DEBUG):
#     349         _debug_log(
#     350             _SERVER_SELECTION_LOGGER,
#     351             message=_ServerSelectionStatusMessage.FAILED,
#    (...)    357             failure=self._error_message(selector),
#     358         )
# --> 359     raise ServerSelectionTimeoutError(
#     360         f"{self._error_message(selector)}, Timeout: {timeout}s, Topology Description: {self.description!r}"
#     361     )
#     363 if not logged_waiting:
#     364     _debug_log(
#     365         _SERVER_SELECTION_LOGGER,
#     366         message=_ServerSelectionStatusMessage.WAITING,
#    (...)    372         remainingTimeMS=int(1000 * (end_time - time.monotonic())),
#     373     )
#
# ServerSelectionTimeoutError: localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 5.0s, Topology Description: <TopologyDescription id: 69b9e5431bf4622d7342efb9, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>

# %%
# RQ1
pipeline1 = [
    {
        "$match": {
            "genre": {"$in": ["Horror", "Action", "Comedy"]},
            "box_office.domestic_gross": {"$ne": None},
            "box_office.foreign_gross": {"$ne": None}
        }
    },
    {
        "$project": {
            "_id": 0,
            "imdb_title_id": 1,
            "title": 1,
            "year": 1,
            "genre": 1,
            "num_recommendations": "$num_reddit_mentions",
            "domestic_gross": "$box_office.domestic_gross",
            "foreign_gross": "$box_office.foreign_gross",
            "total_revenue": {
                "$add": [
                    "$box_office.domestic_gross",
                    "$box_office.foreign_gross"
                ]
            },
            "foreign_share": {
                "$cond": [
                    {
                        "$eq": [
                            {
                                "$add": [
                                    "$box_office.domestic_gross",
                                    "$box_office.foreign_gross"
                                ]
                            },
                            0
                        ]
                    },
                    None,
                    {
                        "$divide": [
                            "$box_office.foreign_gross",
                            {
                                "$add": [
                                    "$box_office.domestic_gross",
                                    "$box_office.foreign_gross"
                                ]
                            }
                        ]
                    }
                ]
            }
        }
    },
    {
        "$sort": {"num_recommendations": -1}
    }
]

results = list(movies_collection.aggregate(pipeline1))
df1 = pd.DataFrame(results)

print(df1.head(10))

# %%
import numpy as np

sql_df = pd.read_csv("rq1.csv")

mongo_df = df1.copy()  

mongo_df = mongo_df.drop(columns=["_id"], errors="ignore")


# clean column names (SUPER IMPORTANT)
sql_df.columns = sql_df.columns.str.strip().str.lower()
mongo_df.columns = mongo_df.columns.str.strip().str.lower()

# drop Mongo _id if it exists
mongo_df = mongo_df.drop(columns=["_id"], errors="ignore")

# check structure
print("SQL columns:", sql_df.columns.tolist())
print("Mongo columns:", mongo_df.columns.tolist())

# %%
print("SQL shape:", sql_df.shape)
print("Mongo shape:", mongo_df.shape)

# %%
# RQ2
pipeline2= [
	{"$match": {
		"box_office.domestic_gross": {"$ne": None},
            	"box_office.foreign_gross": {"$ne": None} 
		}
	}
	{
        "$project": {
            "_id": 0,
            "imdb_title_id": 0,
            "title": 0,
            "year": 0,
            "genre": 0,
            "num_recommendations": "$num_reddit_mentions",
            "total_gross": {
                "$add": [
                    "$box_office.domestic_gross",
                    "$box_office.foreign_gross"
                ]
            },
        }
    },
]

results = list(movies_collection.aggregate(pipeline2))
df1 = pd.DataFrame(results)

print(df1.head(10))
