# %%
import pandas as pd
import pymongo
from pathlib import Path

# Connect to MongoDB
CWL = "bchau01"
SNUM = 76377498

connection_string = f"mongodb://{CWL}:a{SNUM}@localhost:27017/{CWL}"
client = pymongo.MongoClient(connection_string, serverSelectionTimeoutMS=5000)

client.admin.command("ping")
print("Connected to MongoDB.")

db = client[CWL]
movies_collection = db["movies"]

# Load cleaned CSVs
data_path = Path("data_clean")
imdb_df = pd.read_csv(data_path / "imdb_movies_clean.csv")
bom_df = pd.read_csv(data_path / "bom_gross_clean.csv")
sql_df = pd.read_csv("rq1.csv")
# Out:
# Connected to MongoDB.

# %%
sql_join_df = imdb_df.merge(
    bom_df,
    on=["title", "year"],
    how="inner"
)

genre_mask = (
    sql_join_df["genre"].str.contains("Horror", na=False) |
    sql_join_df["genre"].str.contains("Action", na=False) |
    sql_join_df["genre"].str.contains("Comedy", na=False)
)

sql_join_df = sql_join_df[genre_mask]

null_gross_rows = sql_join_df[
    sql_join_df["domestic_gross"].isna() |
    sql_join_df["foreign_gross"].isna()
]

print("SQL-style joined rows after genre filter:", len(sql_join_df))
print("Rows with null domestic_gross or foreign_gross:", len(null_gross_rows))
print(null_gross_rows[["imdb_title_id", "title", "year", "domestic_gross", "foreign_gross"]].head(20))
# Out:
# SQL-style joined rows after genre filter: 415
# Rows with null domestic_gross or foreign_gross: 0
# Empty DataFrame
# Columns: [imdb_title_id, title, year, domestic_gross, foreign_gross]
# Index: []

# %%
sql_join_df = imdb_df.merge(
    bom_df,
    on=["title", "year"],
    how="inner"
)

genre_mask = (
    sql_join_df["genre"].str.contains("Horror", na=False) |
    sql_join_df["genre"].str.contains("Action", na=False) |
    sql_join_df["genre"].str.contains("Comedy", na=False)
)

sql_join_df = sql_join_df[genre_mask]

null_gross_rows = sql_join_df[
    sql_join_df["domestic_gross"].isna() |
    sql_join_df["foreign_gross"].isna()
]

print("SQL-style joined rows after genre filter:", len(sql_join_df))
print("Rows with null domestic_gross or foreign_gross:", len(null_gross_rows))
print(null_gross_rows[["imdb_title_id", "title", "year", "domestic_gross", "foreign_gross"]].head(20))
# Out:
# SQL-style joined rows after genre filter: 415
# Rows with null domestic_gross or foreign_gross: 0
# Empty DataFrame
# Columns: [imdb_title_id, title, year, domestic_gross, foreign_gross]
# Index: []

# %%
# RQ1
pipeline1 = [
    {
        "$match": {
            "genre": {"$in": ["Horror", "Action", "Comedy"]},
            "box_office.domestic_gross": {"$ne": None},
            "box_office.foreign_gross": {"$ne": None}
        }
    },
    {
        "$project": {
            "_id": 0,
            "imdb_title_id": 1,
            "title": 1,
            "year": 1,
            "genre": 1,
            "num_recommendations": "$num_reddit_mentions",
            "domestic_gross": "$box_office.domestic_gross",
            "foreign_gross": "$box_office.foreign_gross",
            "total_revenue": {
                "$add": [
                    "$box_office.domestic_gross",
                    "$box_office.foreign_gross"
                ]
            },
            "foreign_share": {
                "$cond": [
                    {
                        "$eq": [
                            {
                                "$add": [
                                    "$box_office.domestic_gross",
                                    "$box_office.foreign_gross"
                                ]
                            },
                            0
                        ]
                    },
                    None,
                    {
                        "$divide": [
                            "$box_office.foreign_gross",
                            {
                                "$add": [
                                    "$box_office.domestic_gross",
                                    "$box_office.foreign_gross"
                                ]
                            }
                        ]
                    }
                ]
            }
        }
    },
    {
        "$sort": {"num_recommendations": -1}
    }
]

results = list(movies_collection.aggregate(pipeline1))
df1 = pd.DataFrame(results)

print("Mongo rows:", len(df1))
print(df1.head(10))

results = list(movies_collection.aggregate(pipeline1))
df1 = pd.DataFrame(results)

print(df1.head(10))

results = list(movies_collection.aggregate(pipeline1))
df1 = pd.DataFrame(results)

print(df1.head(10))
# Out:
# Mongo rows: 415
#   imdb_title_id                title  year                        genre  \
# 0     tt1375666            inception  2010  [Action, Adventure, Sci-Fi]
# 1     tt2911666            john wick  2014    [Action, Crime, Thriller]
# 2     tt6499752              upgrade  2018   [Action, Sci-Fi, Thriller]
# 3     tt5688932  sorry to bother you  2018    [Comedy, Fantasy, Sci-Fi]
# 4     tt1856101    blade runner 2049  2017     [Action, Drama, Mystery]
# 5     tt1392190    mad max fury road  2015  [Action, Adventure, Sci-Fi]
# 6     tt3397884              sicario  2015       [Action, Crime, Drama]
# 7     tt6998518                mandy  2018    [Action, Fantasy, Horror]
# 8     tt4925292            lady bird  2017              [Comedy, Drama]
# 9     tt3799694        the nice guys  2016      [Action, Comedy, Crime]
#
#    num_recommendations  domestic_gross  foreign_gross  total_revenue  \
# 0                  462       292576195      542948447      835524642
# 1                  316        43037835       33197166       76235001
# 2                  292        11977130        4576155       16553285
# 3                  292        17493096         792464       18285560
# 4                  280        92054159      167303249      259357408
# 5                  266       153636354      216461666      370098020
# 6                  263        46889293       37504456       84393749
# 7                  262         1214525         213131        1427656
# 8                  238        48958273       29652496       78610769
# 9                  232        36261763       23334984       59596747
#
#    foreign_share
# 0       0.649829
# 1       0.435458
# 2       0.276450
# 3       0.043338
# 4       0.645068
# 5       0.584877
# 6       0.444399
# 7       0.149287
# 8       0.377207
# 9       0.391548
#   imdb_title_id                title  year                        genre  \
# 0     tt1375666            inception  2010  [Action, Adventure, Sci-Fi]
# 1     tt2911666            john wick  2014    [Action, Crime, Thriller]
# 2     tt6499752              upgrade  2018   [Action, Sci-Fi, Thriller]
# 3     tt5688932  sorry to bother you  2018    [Comedy, Fantasy, Sci-Fi]
# 4     tt1856101    blade runner 2049  2017     [Action, Drama, Mystery]
# 5     tt1392190    mad max fury road  2015  [Action, Adventure, Sci-Fi]
# 6     tt3397884              sicario  2015       [Action, Crime, Drama]
# 7     tt6998518                mandy  2018    [Action, Fantasy, Horror]
# 8     tt4925292            lady bird  2017              [Comedy, Drama]
# 9     tt3799694        the nice guys  2016      [Action, Comedy, Crime]
#
#    num_recommendations  domestic_gross  foreign_gross  total_revenue  \
# 0                  462       292576195      542948447      835524642
# 1                  316        43037835       33197166       76235001
# 2                  292        11977130        4576155       16553285
# 3                  292        17493096         792464       18285560
# 4                  280        92054159      167303249      259357408
# 5                  266       153636354      216461666      370098020
# 6                  263        46889293       37504456       84393749
# 7                  262         1214525         213131        1427656
# 8                  238        48958273       29652496       78610769
# 9                  232        36261763       23334984       59596747
#
#    foreign_share
# 0       0.649829
# 1       0.435458
# 2       0.276450
# 3       0.043338
# 4       0.645068
# 5       0.584877
# 6       0.444399
# 7       0.149287
# 8       0.377207
# 9       0.391548
#   imdb_title_id                title  year                        genre  \
# 0     tt1375666            inception  2010  [Action, Adventure, Sci-Fi]
# 1     tt2911666            john wick  2014    [Action, Crime, Thriller]
# 2     tt6499752              upgrade  2018   [Action, Sci-Fi, Thriller]
# 3     tt5688932  sorry to bother you  2018    [Comedy, Fantasy, Sci-Fi]
# 4     tt1856101    blade runner 2049  2017     [Action, Drama, Mystery]
# 5     tt1392190    mad max fury road  2015  [Action, Adventure, Sci-Fi]
# 6     tt3397884              sicario  2015       [Action, Crime, Drama]
# 7     tt6998518                mandy  2018    [Action, Fantasy, Horror]
# 8     tt4925292            lady bird  2017              [Comedy, Drama]
# 9     tt3799694        the nice guys  2016      [Action, Comedy, Crime]
#
#    num_recommendations  domestic_gross  foreign_gross  total_revenue  \
# 0                  462       292576195      542948447      835524642
# 1                  316        43037835       33197166       76235001
# 2                  292        11977130        4576155       16553285
# 3                  292        17493096         792464       18285560
# 4                  280        92054159      167303249      259357408
# 5                  266       153636354      216461666      370098020
# 6                  263        46889293       37504456       84393749
# 7                  262         1214525         213131        1427656
# 8                  238        48958273       29652496       78610769
# 9                  232        36261763       23334984       59596747
#
#    foreign_share
# 0       0.649829
# 1       0.435458
# 2       0.276450
# 3       0.043338
# 4       0.645068
# 5       0.584877
# 6       0.444399
# 7       0.149287
# 8       0.377207
# 9       0.391548

# %%
# see if mongoDB and SQL output are similar
import numpy as np

sql_df = pd.read_csv("rq1.csv")

mongo_df = df1.copy()  

mongo_df = mongo_df.drop(columns=["_id"], errors="ignore")

sql_df.columns = sql_df.columns.str.strip().str.lower()
mongo_df.columns = mongo_df.columns.str.strip().str.lower()

mongo_df = mongo_df.drop(columns=["_id"], errors="ignore")

# check structure
print("SQL columns:", sql_df.columns.tolist())
print("Mongo columns:", mongo_df.columns.tolist())
# Out:
# SQL columns: ['imdb_title_id', 'title', 'year', 'genre', 'num_recommendations', 'domestic_gross', 'foreign_gross', 'total_revenue', 'foreign_share']
# Mongo columns: ['imdb_title_id', 'title', 'year', 'genre', 'num_recommendations', 'domestic_gross', 'foreign_gross', 'total_revenue', 'foreign_share']

# %%
print("SQL shape:", sql_df.shape)
print("Mongo shape:", mongo_df.shape)
# Out:
# SQL shape: (449, 9)
# Mongo shape: (415, 9)

# %%
sql_df = pd.read_csv("rq1.csv")
sql_df.columns = sql_df.columns.str.strip().str.lower()

dup_sql = (
    sql_df.groupby(["imdb_title_id", "title", "year"])
    .size()
    .reset_index(name="count")
)

dup_sql = dup_sql[dup_sql["count"] > 1]

print("Duplicated movie keys in rq1.csv:", len(dup_sql))
print("Extra duplicated SQL rows:", (dup_sql["count"] - 1).sum())
print(dup_sql.sort_values("count", ascending=False).head(20))
# Out:
# Duplicated movie keys in rq1.csv: 32
# Extra duplicated SQL rows: 33
#        imdb_title_id                                              title  \
# 357  tt3567288        the visit                                     ...
# 34   tt0974015        justice league                                ...
# 71   tt1211837        doctor strange                                ...
# 395  tt5127300        forsaken                                      ...
# 391  tt4925292        lady bird                                     ...
# 388  tt4765284        pitch perfect 3                               ...
# 366  tt3783958        la la land                                    ...
# 363  tt3748528        rogue one a star wars story                   ...
# 352  tt3521126        the disaster artist                           ...
# 349  tt3501632        thor ragnarok                                 ...
# 346  tt3470600        sing                                          ...
# 345  tt3411444        ferdinand                                     ...
# 344  tt3397884        sicario                                       ...
# 343  tt3381068        legend                                        ...
# 334  tt3164256        rock the kasbah                               ...
# 329  tt3062096        inferno                                       ...
# 308  tt2719848        everest                                       ...
# 297  tt2554274        crimson peak                                  ...
# 289  tt2401878        anomalisa                                     ...
# 285  tt2379713        spectre                                       ...
#
#            year  count
# 357        2015      3
# 34         2017      2
# 71         2016      2
# 395        2016      2
# 391        2017      2
# 388        2017      2
# 366        2016      2
# 363        2016      2
# 352        2017      2
# 349        2017      2
# 346        2016      2
# 345        2017      2
# 344        2015      2
# 343        2015      2
# 334        2015      2
# 329        2016      2
# 308        2015      2
# 297        2015      2
# 289        2015      2
# 285        2015      2

# %%
df1.columns = df1.columns.str.strip().str.lower()

sql_keys = set(zip(sql_df["imdb_title_id"], sql_df["title"], sql_df["year"]))
mongo_keys = set(zip(df1["imdb_title_id"], df1["title"], df1["year"]))

missing_in_mongo = sql_keys - mongo_keys
extra_in_mongo = mongo_keys - sql_keys

print("Rows in SQL but not Mongo:", len(missing_in_mongo))
print("Rows in Mongo but not SQL:", len(extra_in_mongo))

missing_df = pd.DataFrame(list(missing_in_mongo), columns=["imdb_title_id", "title", "year"])
extra_df = pd.DataFrame(list(extra_in_mongo), columns=["imdb_title_id", "title", "year"])

print("\nMissing in Mongo:")
print(missing_df.sort_values(["year", "title"]).head(50))

print("\nExtra in Mongo:")
print(extra_df.sort_values(["year", "title"]).head(50))
# Out:
# Rows in SQL but not Mongo: 416
# Rows in Mongo but not SQL: 415
#
# Missing in Mongo:
#        imdb_title_id                                              title  \
# 146  tt0393049        andersons cross                               ...
# 333  tt1431181        another year                                  ...
# 140  tt1020558        centurion                                     ...
# 58   tt1129412        circle                                        ...
# 276  tt1336617        cyrus                                         ...
# 412  tt1327709        cyrus                                         ...
# 298  tt1314655        devil                                         ...
# 296  tt1232775        drones                                        ...
# 253  tt1433108        faster                                        ...
# 299  tt1341167        four lions                                    ...
# 4    tt0947810        green zone                                    ...
# 132  tt1242432        i spit on your grave                          ...
# 207  tt1261862        icarus                                        ...
# 63   tt1375666        inception                                     ...
# 304  tt1228705        iron man 2                                    ...
# 306  tt1075747        jonah hex                                     ...
# 378  tt1250777        kickass                                       ...
# 414  tt1103153        killers                                       ...
# 84   tt1198101        kites                                         ...
# 237  tt1038686        legion                                        ...
# 125  tt0892318        letters to juliet                             ...
# 312  tt0979434        lottery ticket                                ...
# 375  tt1125929        love ranch                                    ...
# 55   tt1470023        macgruber                                     ...
# 26   tt0985694        machete                                       ...
# 85   tt1001526        megamind                                      ...
# 45   tt1536044        paranormal activity 2                         ...
# 205  tt0464154        piranha 3d                                    ...
# 231  tt0878835        please give                                   ...
# 39   tt1424381        predators                                     ...
# 46   tt0493949        ramona and beezus                             ...
# 344  tt1053424        repo men                                      ...
# 127  tt1220634        resident evil afterlife                       ...
# 53   tt0955308        robin hood                                    ...
# 238  tt0944835        salt                                          ...
# 183  tt1261945        sex and the city 2                            ...
# 278  tt1564585        skyline                                       ...
# 235  tt1421051        somewhere                                     ...
# 100  tt1135084        takers                                        ...
# 313  tt0923653        the dead undead                               ...
# 7    tt0480255        the losers                                    ...
# 179  tt1458175        the next three days                           ...
# 308  tt1320291        the reef                                      ...
# 148  tt1243957        the tourist                                   ...
# 142  tt1695994        the virginity hit                             ...
# 66   tt1032751        the warriors way                              ...
# 128  tt1570989        tiny furniture                                ...
# 130  tt1391137        why did i get married too                     ...
# 370  tt1622547        30 minutes or less                            ...
# 96   tt1486193        5 days of war                                 ...
#
#            year
# 146        2010
# 333        2010
# 140        2010
# 58         2010
# 276        2010
# 412        2010
# 298        2010
# 296        2010
# 253        2010
# 299        2010
# 4          2010
# 132        2010
# 207        2010
# 63         2010
# 304        2010
# 306        2010
# 378        2010
# 414        2010
# 84         2010
# 237        2010
# 125        2010
# 312        2010
# 375        2010
# 55         2010
# 26         2010
# 85         2010
# 45         2010
# 205        2010
# 231        2010
# 39         2010
# 46         2010
# 344        2010
# 127        2010
# 53         2010
# 238        2010
# 183        2010
# 278        2010
# 235        2010
# 100        2010
# 313        2010
# 7          2010
# 179        2010
# 308        2010
# 148        2010
# 142        2010
# 66         2010
# 128        2010
# 130        2010
# 370        2011
# 96         2011
#
# Extra in Mongo:
#     imdb_title_id                      title  year
# 57      tt0393049            andersons cross  2010
# 397     tt1431181               another year  2010
# 389     tt1020558                  centurion  2010
# 209     tt1129412                     circle  2010
# 116     tt1336617                      cyrus  2010
# 211     tt1327709                      cyrus  2010
# 334     tt1314655                      devil  2010
# 313     tt1232775                     drones  2010
# 340     tt1433108                     faster  2010
# 241     tt1341167                 four lions  2010
# 110     tt0947810                 green zone  2010
# 117     tt1242432       i spit on your grave  2010
# 252     tt1261862                     icarus  2010
# 281     tt1375666                  inception  2010
# 192     tt1228705                 iron man 2  2010
# 385     tt1075747                  jonah hex  2010
# 52      tt1250777                    kickass  2010
# 62      tt1103153                    killers  2010
# 188     tt1198101                      kites  2010
# 15      tt1038686                     legion  2010
# 262     tt0892318          letters to juliet  2010
# 370     tt0979434             lottery ticket  2010
# 175     tt1125929                 love ranch  2010
# 198     tt1470023                  macgruber  2010
# 187     tt0985694                    machete  2010
# 196     tt1001526                   megamind  2010
# 380     tt1536044      paranormal activity 2  2010
# 34      tt0464154                 piranha 3d  2010
# 133     tt0878835                please give  2010
# 208     tt1424381                  predators  2010
# 298     tt0493949          ramona and beezus  2010
# 384     tt1053424                   repo men  2010
# 43      tt1220634    resident evil afterlife  2010
# 237     tt0955308                 robin hood  2010
# 92      tt0944835                       salt  2010
# 98      tt1261945         sex and the city 2  2010
# 126     tt1564585                    skyline  2010
# 40      tt1421051                  somewhere  2010
# 373     tt1135084                     takers  2010
# 251     tt0923653            the dead undead  2010
# 22      tt0480255                 the losers  2010
# 190     tt1458175        the next three days  2010
# 80      tt1320291                   the reef  2010
# 86      tt1243957                the tourist  2010
# 144     tt1695994          the virginity hit  2010
# 47      tt1032751           the warriors way  2010
# 173     tt1570989             tiny furniture  2010
# 231     tt1391137  why did i get married too  2010
# 265     tt1622547         30 minutes or less  2011
# 124     tt1486193              5 days of war  2011
